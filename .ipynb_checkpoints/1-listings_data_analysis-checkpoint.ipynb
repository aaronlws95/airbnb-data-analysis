# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
from IPython.display import display
from transformers import pipeline
from tqdm.notebook import tqdm
pd.options.plotting.backend = "plotly"
# %matplotlib inline

# %% [markdown]
# ## Load data
#
# We will use the [Seattle Airbnb Open Data](https://www.kaggle.com/airbnb/seattle/data) to help us with our understanding

# %%
data_folder_name = "data/seattle"
csv_files = Path(data_folder_name).glob("*.csv")
csv_files = [x for x in csv_files]

# %%
[str(x.name).split(".")[0] for x in csv_files]
# Out:
# ['reviews', 'calendar', 'listings', 'review_sentiments_v1']

# %%
dfs = {}
for x in csv_files:
    dfs[str(x.name).split(".")[0]] = pd.read_csv(x)

# %% [markdown]
# ## First look at the data

# %%
def display_df_info(df):
    """
    Display info from the dataframe
    
    Input:
        df: Pandas dataframe
        
    Output:
        None: 
    """
    print("Shape:", df.shape)
    display(df)
    percentage_missing = df.isnull().sum() * 100 / len(df)
    percentage_missing_df = pd.DataFrame({"percentage_missing/%": percentage_missing})
    display(percentage_missing_df.sort_values("percentage_missing/%", ascending=False).head(10))

# %%
display_df_info(dfs["reviews"])
# Out:
# Shape: (84849, 6)
#        listing_id        id        date  reviewer_id reviewer_name  \
# 0         7202016  38917982  2015-07-19     28943674        Bianca
# 1         7202016  39087409  2015-07-20     32440555         Frank
# 2         7202016  39820030  2015-07-26     37722850           Ian
# 3         7202016  40813543  2015-08-02     33671805        George
# 4         7202016  41986501  2015-08-10     34959538          Ming
# ...           ...       ...         ...          ...           ...
# 84844     3624990  50436321  2015-10-12     37419458          Ryan
# 84845     3624990  51024875  2015-10-17      6933252         Linda
# 84846     3624990  51511988  2015-10-20     19543701         Jaime
# 84847     3624990  52814482  2015-11-02     24445024        Jørgen
# 84848     9727246  56429621  2015-12-13     30860360     Stephanie
#
#                                                 comments
# 0      Cute and cozy place. Perfect location to every...
# ...

# %%
display_df_info(dfs["calendar"])
# Out:
# Shape: (1393570, 4)
#          listing_id        date available   price
# 0            241032  2016-01-04         t  $85.00
# 1            241032  2016-01-05         t  $85.00
# 2            241032  2016-01-06         f     NaN
# 3            241032  2016-01-07         f     NaN
# 4            241032  2016-01-08         f     NaN
# ...             ...         ...       ...     ...
# 1393565    10208623  2016-12-29         f     NaN
# 1393566    10208623  2016-12-30         f     NaN
# 1393567    10208623  2016-12-31         f     NaN
# 1393568    10208623  2017-01-01         f     NaN
# 1393569    10208623  2017-01-02         f     NaN
#
# [1393570 rows x 4 columns]
#             percentage_missing/%
# price                  32.938998
# listing_id              0.000000
# date                    0.000000
# available               0.000000

# %%
display_df_info(dfs["listings"])
# Out:
# Shape: (3818, 92)
#             id                            listing_url       scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  20160104002432
# 1       953595    https://www.airbnb.com/rooms/953595  20160104002432
# 2      3308979   https://www.airbnb.com/rooms/3308979  20160104002432
# 3      7421966   https://www.airbnb.com/rooms/7421966  20160104002432
# 4       278830    https://www.airbnb.com/rooms/278830  20160104002432
# ...        ...                                    ...             ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 3814   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                 name  \
# ...

# %% [markdown]
# #### Columns in listings.csv

# %%
for i, x in enumerate(dfs["listings"].columns):
    print("{}: {}".format(i, x))
# Out:
# 0: id
# 1: listing_url
# 2: scrape_id
# 3: last_scraped
# 4: name
# 5: summary
# 6: space
# 7: description
# 8: experiences_offered
# 9: neighborhood_overview
# 10: notes
# 11: transit
# 12: thumbnail_url
# 13: medium_url
# 14: picture_url
# 15: xl_picture_url
# 16: host_id
# 17: host_url
# 18: host_name
# 19: host_since
# 20: host_location
# 21: host_about
# 22: host_response_time
# 23: host_response_rate
# 24: host_acceptance_rate
# 25: host_is_superhost
# 26: host_thumbnail_url
# 27: host_picture_url
# 28: host_neighbourhood
# 29: host_listings_count
# 30: host_total_listings_count
# 31: host_verifications
# 32: host_has_profile_pic
# 33: host_identity_verified
# 34: street
# 35: neighbourhood
# 36: neighbourhood_cleansed
# 37: neighbourhood_group_cleansed
# 38: city
# 39: state
# 40: zipcode
# 41: market
# 42: smart_location
# 43: country_code
# 44: country
# 45: latitude
# 46: longitude
# 47: is_location_exact
# 48: property_type
# 49: room_type
# 50: accommodates
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Let's take a look at the data for listings. First we start with cleaning the data.

# %%
df_listings = dfs["listings"].copy()

# %%
before_cols = df_listings.shape[1]
# Remove columns with all missing values
df_listings = df_listings.dropna(how="all", axis=1)
# Remove columns with redundant data
for col in df_listings.columns:
    if len((df_listings[col]).unique())==1:
        df_listings = df_listings.drop(col, axis=1)
after_cols = df_listings.shape[1]
print("We removed {} redundant columns".format(before_cols - after_cols))
# Out:
# We removed 11 redundant columns

# %%
review_scores_cols = [x for x in df_listings.columns if "review_scores" in x]
# Remove all rows with invalid reviews
df_listings = df_listings.dropna(how="all", subset=review_scores_cols)
# Remove rows with no number of reviews
df_listings = df_listings.dropna(how="any", subset=["number_of_reviews"])
# # Fill missing reviews with 0
df_listings[review_scores_cols] = df_listings[review_scores_cols].fillna(0)

# %%
# Make columns numeric
df_listings["host_response_rate"] = df_listings["host_response_rate"].apply(lambda x: float(str(x).replace("%", ""))/100)
df_listings["host_acceptance_rate"] = df_listings["host_acceptance_rate"].apply(lambda x: float(str(x).replace("%", ""))/100)
df_listings["num_amenities"] = df_listings["amenities"].apply(lambda x: len(x.split(",")))
df_listings["price"] = df_listings["price"].apply(lambda x: float(str(x).replace("$", "").replace(",", "")))
df_listings["weekly_price"] = df_listings["weekly_price"].apply(lambda x: float(str(x).replace("$", "").replace(",", "")))
df_listings["monthly_price"] = df_listings["monthly_price"].apply(lambda x: float(str(x).replace("$", "").replace(",", "")))
df_listings["security_deposit"] = df_listings["security_deposit"].apply(lambda x: float(str(x).replace("$", "").replace(",", "")))
df_listings["cleaning_fee"] = df_listings["cleaning_fee"].apply(lambda x: float(str(x).replace("$", "").replace(",", "")))
df_listings["extra_people_cost"] = df_listings["extra_people"].apply(lambda x: float(str(x).replace("$", "").replace(",", "")))

# %%
# Fix bool columns
df_listings["host_is_superhost"] = df_listings["host_is_superhost"].apply(lambda x: x == "t")
df_listings["host_has_profile_pic"] = df_listings["host_has_profile_pic"].apply(lambda x: x == "t")
df_listings["host_identity_verified"] = df_listings["host_identity_verified"].apply(lambda x: x == "t")
df_listings["require_guest_profile_picture"] = df_listings["require_guest_profile_picture"].apply(lambda x: x == "t")
df_listings["require_guest_phone_verification"] = df_listings["require_guest_phone_verification"].apply(lambda x: x == "t")
df_listings["instant_bookable"] = df_listings["instant_bookable"].apply(lambda x: x == "t")

# %% [markdown]
# ### Since there are 7 columns for scoring the listing, we will aggregate them so that we have a single value to compare listings.

# %%
def aggregate_review_score(x):
    """
    Aggregate the review score for listings
    Input:
        x: One row from dataframe
    Output:
        out: Aggregated review score
    """
    score = x["review_scores_rating"]/10 + \
            x["review_scores_accuracy"] + \
            x["review_scores_cleanliness"] + \
            x["review_scores_checkin"] + \
            x["review_scores_communication"] + \
            x["review_scores_location"] + \
            x["review_scores_value"] 
    score = (score/7)
    
    return score

# %%
df_listings["aggregate_score"] = [aggregate_review_score(x) for _, x in df_listings.iterrows()]

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Let's have a look at the distribution of scores in the data

# %%
df_listings.plot(kind="scatter", x="aggregate_score", y="number_of_reviews").update_layout(showlegend=False)
# Out:
# <div>                            <div id="00c0a9b0-b828-4f14-b972-bc596968dd90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00c0a9b0-b828-4f14-b972-bc596968dd90")) {                    Plotly.newPlot(                        "00c0a9b0-b828-4f14-b972-bc596968dd90",                        [{"hovertemplate": "aggregate_score=%{x}<br>number_of_reviews=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [9.785714285714286, 9.942857142857141, 9.957142857142857, 9.314285714285715, 9.928571428571429, 9.985714285714286, 9.814285714285715, 9.671428571428573, 9.814285714285715, 9.957142857142857, 9.671428571428573, 9.971428571428572, 9.7142
# ...

# %% [markdown]
# #### We see that a higher number of reviews leads to a higher aggregate score. One possibility could be that users who review generally prefer to give a higher score. Also, there could be a positive feedback where listings with higher reviews also attract more people which results in more reviews whereas those with bad reviews may not get new guests.

# %% [markdown]
# ### To gain some insights on the traits of top performers, we will take an equal number of top and bottom performers from the data to compare.

# %%
# Separate into top and bottom performers
df_listings["aggregate_score_quantile"] = pd.qcut(df_listings["aggregate_score"], q=10, labels=list(range(9)), duplicates="drop").astype(int)
df_listings_topbottom = df_listings[df_listings["aggregate_score_quantile"].isin([0, 1, 8])].copy()
df_listings_topbottom["aggregate_score_quantile"] = df_listings_topbottom["aggregate_score_quantile"].replace(8, "Top Performer")
df_listings_topbottom["aggregate_score_quantile"] = df_listings_topbottom["aggregate_score_quantile"].replace(0, "Bottom Performer")
df_listings_topbottom["aggregate_score_quantile"] = df_listings_topbottom["aggregate_score_quantile"].replace(1, "Bottom Performer")
df_listings_topbottom["aggregate_score_quantile"].value_counts()
# Out:
# Bottom Performer    641
# Top Performer       632
# Name: aggregate_score_quantile, dtype: int64

# %%
# Plot against host_response_time
tmp_df = df_listings_topbottom.groupby(["host_response_time", "aggregate_score_quantile"]).size().unstack()
tmp_df["Absolute Difference"] = [np.abs(x["Top Performer"] - x["Bottom Performer"]) for _, x in tmp_df.iterrows()]
tmp_df.plot(kind='bar', labels={"value": "count"})
# Out:
# <div>                            <div id="ae1d5d40-70d0-4d13-8177-17561fd40ca5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae1d5d40-70d0-4d13-8177-17561fd40ca5")) {                    Plotly.newPlot(                        "ae1d5d40-70d0-4d13-8177-17561fd40ca5",                        [{"alignmentgroup": "True", "hovertemplate": "aggregate_score_quantile=Bottom Performer<br>host_response_time=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Bottom Performer", "marker": {"color": "#636efa"}, "name": "Bottom Performer", "offsetgroup": "Bottom Performer", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["a few days or more", "within a day", "within a few hours", "within an hour"], "xaxis": "x", "y": [12, 112,
# ...

# %%
 df_listings_topbottom.groupby(""

# %% [markdown]
# #### No surprises here, we see that the more responsive the host is are the better your score will be

# %%
drop_cols = ["id", "host_id", "latitude", "longitude", "aggregate_score"]
sns.heatmap(df_listings.drop(drop_cols + review_scores_cols, axis=1).corr(), cmap='viridis');

# %% [markdown]
# #### Let's look at the statistics for reviews for each listing

# %%
dfs["reviews"].groupby("listing_id").count()["id"].describe()
# Out:
# count    3191.000000
# mean       26.590097
# std        39.840788
# min         1.000000
# 25%         4.000000
# 50%        13.000000
# 75%        31.000000
# max       474.000000
# Name: id, dtype: float64

# %% [markdown]
# #### Now let's use a sentiment classifer from [HuggingFace transfomers](https://huggingface.co/transformers/index.html) to see how well the listings are doing
#
# The model used is [DistilBERT](https://huggingface.co/transformers/model_doc/distilbert.html) fine-tuned on [SST-2](https://www.kaggle.com/atulanandjha/stanford-sentiment-treebank-v2-sst2). The output of the model is a label (either POSITIVE or NEGATIVE) and a score showing how "confident" the label is.

# %% [markdown]
# #### This might take a couple hours, let's save the values to a file so we will run this only once

# %%
sentiment_csv_file = "reviews_sentiment_predictions"

# %%
# %run ./estimate_review_sentiments.py -i data_folder_name -o sentiment_csv_file

# %% [markdown]
# #### Now let's see which listings did well

# %%
# Load values to dataframe
sentiment_df = pd.read_csv(Path(data_folder_name)/(sentiment_csv_file + ".csv"))
for col in sentiment_df.columns:
    if col != "review_id":
        dfs["reviews"][col] = sentiment_df[col]

# %%
# Remove entries with faulty comments
dfs["reviews"] = dfs["reviews"][dfs["reviews"]["positive_score"].notna()]

# %%
def sentiment_score(positive, negative, neutral):
    """
    Calculate sentiment score = (positive - negative)/(positive + negative + neutral)
    Input:
        positive: number of positive sentences
        negative: number of negative sentences
        neutral: number of neutral sentences
    Output:
        sentiment score
    """
    
    return (positive - negative)/(positive + negative + neutral)

# %%
# Get sentiment scores for each comment
dfs["reviews"]["sentiment_score"] = [sentiment_score(x["positive"], x["negative"], x["neutral"]) 
                                     for x in dfs["reviews"]]

# %%
dfs["reviews"].groupby("listing_id")["sentiment_score"].describe()
